# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from functions import weather_generator, count_anomalies

# %%
# Use the weather_generator function to generate weather
# data for switzerland
mean = 0.0
sigma = 0.94
n = 100000

# Generate weather data
weather = weather_generator(mean, sigma, n)

# %%
# For our data array we count the number of values that are
# greater than 5.1
count = count_anomalies(weather, 4)
print(count)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /workspaces/MTMA33_Computing/practical_4/practical_4.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell://codespaces%2Bpotential-orbit-r9gx7q49jqw2xxq9/workspaces/MTMA33_Computing/practical_4/practical_4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # For our data array we count the number of values that are
#       <a href='vscode-notebook-cell://codespaces%2Bpotential-orbit-r9gx7q49jqw2xxq9/workspaces/MTMA33_Computing/practical_4/practical_4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # greater than 5.1
# ----> <a href='vscode-notebook-cell://codespaces%2Bpotential-orbit-r9gx7q49jqw2xxq9/workspaces/MTMA33_Computing/practical_4/practical_4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> count = count_anomalies(weather, 4)
#       <a href='vscode-notebook-cell://codespaces%2Bpotential-orbit-r9gx7q49jqw2xxq9/workspaces/MTMA33_Computing/practical_4/practical_4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> print(count)
#
# File /workspaces/MTMA33_Computing/practical_4/functions.py:55, in count_anomalies(data, threshold)
#      52 assert isinstance(data, np.ndarray), "Data must be a numpy array"
#      54 # Assert that the threshold is a float
# ---> 55 assert isinstance(threshold, float), "Threshold must be a float"
#      57 # Count the number of anomalies
#      58 count = 0
#
# AssertionError: Threshold must be a float
